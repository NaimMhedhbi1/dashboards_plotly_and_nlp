# %%
import pandas as pd
import numpy as np 

import pandas as pd
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk 
import string
import re
import numpy as np
from wordcloud import WordCloud 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import TweetTokenizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
train= pd.read_csv("C:/Users/121/Documents/mariem_sentiment_analysis/train.csv", sep=',', error_bad_lines=False , encoding ='ISO-8859-1')
test = pd.read_csv("C:/Users/121/Documents/mariem_sentiment_analysis/test.csv", sep=',', error_bad_lines=False , encoding ='ISO-8859-1')
# Out:
# b'Skipping line 982: expected 3 fields, saw 4\nSkipping line 1902: expected 3 fields, saw 4\nSkipping line 2939: expected 3 fields, saw 5\nSkipping line 3574: expected 3 fields, saw 5\nSkipping line 5300: expected 3 fields, saw 5\nSkipping line 7069: expected 3 fields, saw 7\nSkipping line 7516: expected 3 fields, saw 4\nSkipping line 7573: expected 3 fields, saw 5\nSkipping line 7583: expected 3 fields, saw 4\nSkipping line 7584: expected 3 fields, saw 4\nSkipping line 7587: expected 3 fields, saw 4\nSkipping line 7629: expected 3 fields, saw 4\nSkipping line 7669: expected 3 fields, saw 4\nSkipping line 8003: expected 3 fields, saw 5\nSkipping line 8032: expected 3 fields, saw 4\nSkipping line 8301: expected 3 fields, saw 4\nSkipping line 8406: expected 3 fields, saw 4\nSkipping line 8501: expected 3 fields, saw 4\nSkipping line 8510: expected 3 fields, saw 4\nSkipping line 8578: expected 3 fields, saw 5\nSkipping line 8584: expected 3 fields, saw 5\nSkipping line 8596: expected 3 fields, saw 4\nSkipping line 8643: expected 3 fields, saw 4\nSkipping line 8761: expected 3 fields, saw 5\nSkipping line 8831: expected 3 fields, saw 4\nSkipping line 8832: expected 3 fields, saw 4\nSkipping line 8833: expected 3 fields, saw 4\nSkipping line 8834: expected 3 fields, saw 4\nSkipping line 8835: expected 3 fields, saw 4\nSkipping line 8836: expected 3 fields, saw 4\nSkipping line 8837: expected 3 fields, saw 4\nSkipping line 8838: expected 3 fields, saw 4\nSkipping line 8954: expected 3 fields, saw 4\nSkipping line 8961: expected 3 fields, saw 6\nSkipping line 9042: expected 3 fields, saw 6\nSkipping line 9072: expected 3 fields, saw 4\nSkipping line 9174: expected 3 fields, saw 4\nSkipping line 9259: expected 3 fields, saw 4\nSkipping line 9368: expected 3 fields, saw 4\nSkipping line 9446: expected 3 fields, saw 4\nSkipping line 9448: expected 3 fields, saw 4\nSkipping line 9452: expected 3 fields, saw 4\nSkipping line 9464: expected 3 fields, saw 4\nSkipping line 9488: expected 3 fields, saw 4\nSkipping line 9594: expected 3 fields, saw 4\nSkipping line 9605: expected 3 fields, saw 5\nSkipping line 9608: expected 3 fields, saw 4\nSkipping line 9664: expected 3 fields, saw 6\nSkipping line 9686: expected 3 fields, saw 4\nSkipping line 9697:
3\nSkipping line 294782: expected 2 fields, saw 3\nSkipping line 295581: expected 2 fields, saw 4\nSkipping line 295631: expected 2 fields, saw 4\nSkipping line 295636: expected 2 fields, saw 4\nSkipping line 295780: expected 2 fields, saw 3\nSkipping line 297853: expected 2 fields, saw 3\nSkipping line 298118: expected 2 fields, saw 3\nSkipping line 298173: expected 2 fields, saw 3\nSkipping line 298874: expected 2 fields, saw 5\n'

# %%
train
# Out:
#                                                   ItemID Sentiment  \
# 0                                                      1         0
# 1                                                      2         0
# 2                                                      3         1
# 3                                                      4         0
# 4                                                      5         0
# ...                                                  ...       ...
# 99785                                              99996         0
# 99786  99997,1,"@cupcake__ arrrr we both replied to e...       NaN
# 99787                                              99998         0
# 99788                                              99999         1
# 99789                                             100000         1
#
#                                SentimentText;;;;;;;;;;;;
# 0                           is so sad for my APL frie...
# 1                         I missed the New Moon trail...
# 2                    omg its already 7:30 :O;;;;;;;;;;;;
# 3                .. Omgaga. Im sooo  im gunna CRy. I'...
# 4               i think mi bf is cheating on me!!!   ...
# ...                                                  ...
# 99785  @Cupcake  seems like a repeating problem   hop...
# 99786                                                NaN
# 99787         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 99788  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99789        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [99790 rows x 3 columns]

# %%
train = train.rename(columns={"SentimentText;;;;;;;;;;;;": "SentimentText"}) 
print(train.columns.tolist())
# Out:
# ['ItemID', 'Sentiment', 'SentimentText']

# %%
print(train.columns.tolist())
# Out:
# ['ItemID', 'Sentiment', 'SentimentText']

# %%
test = test.rename(columns={"SentimentText;;;;;;;;;;;;;;;;;;;": "SentimentText"})

# %%
test
# Out:
#                                                    ItemID  \
# 0                                                       1
# 1                                                       2
# 2                                                       3
# 3                                                       4
# 4                                                       5
# ...                                                   ...
# 299040  299996,"@martine2323 'Morning, Petal - work br...
# 299041  299997,"@martinetrene Hello,little bird!  i fi...
# 299042                                             299998
# 299043                                             299999
# 299044                                             300000
#
#                                             SentimentText
# 0                           is so sad for my APL frien...
# 1                          httI missed the New Moon tr...
# 2                     omg its already 7:30 :O;;;;;;;;;...
# 3                 .. Omgaga. Im sooo  im gunna CRy. I'...
# 4                i think mi bf is cheating on me!!!   ...
# ...                                                   ...
# 299040                                                NaN
# 299041                                                NaN
# 299042  @MartinezMayra I got u at work when I go buy o...
# 299043  @martinfaux He certainly gives good interview ...
# 299044  @martinfaux we've the feedback about our brows...
#
# [299045 rows x 2 columns]

# %%
print('Average count of phrases per sentence in train is {0:.0f}.'.format(train.groupby('ItemID')['SentimentText'].count().mean()))
print('Average count of phrases per sentence in test is {0:.0f}.'.format(test.groupby('ItemID')['SentimentText'].count().mean()))
# Out:
# Average count of phrases per sentence in train is 1.
# Average count of phrases per sentence in test is 1.

# %%
print('Number of phrases in train: {}. Number of sentences in train: {}.'.format(train.shape[0], len(train.ItemID.unique())))
print('Number of phrases in test: {}. Number of sentences in test: {}.'.format(test.shape[0], len(test.ItemID.unique())))
# Out:
# Number of phrases in train: 99790. Number of sentences in train: 99790.
# Number of phrases in test: 299045. Number of sentences in test: 299045.

# %%
train['SentimentText'] = train['SentimentText'].astype(str) 
test['SentimentText'] = test['SentimentText'].astype(str) 
print('Average word length of phrases in train is {0:.0f}.'.format(np.mean(train['SentimentText'].apply(lambda x: len(x.split())))))
print('Average word length of phrases in test is {0:.0f}.'.format(np.mean(test['SentimentText'].apply(lambda x: len(x.split())))))
# Out:
# Average word length of phrases in train is 10.
# Average word length of phrases in test is 10.

# %%
train = train[train['SentimentText'].notna()]
train = train[train['Sentiment'].notna()]
train
# Out:
#        ItemID Sentiment                                      SentimentText
# 0           1         0                       is so sad for my APL frie...
# 1           2         0                     I missed the New Moon trail...
# 2           3         1                omg its already 7:30 :O;;;;;;;;;;;;
# 3           4         0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5         0           i think mi bf is cheating on me!!!   ...
# ...       ...       ...                                                ...
# 99784   99995         0  @cupati It took me waaay too long to get your ...
# 99785   99996         0  @Cupcake  seems like a repeating problem   hop...
# 99787   99998         0         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 99788   99999         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99789  100000         1        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [76949 rows x 3 columns]

# %%
value = train['Sentiment'].value_counts()
value
# Out:
# 1                                                                                                            41696
# 0                                                                                                            33484
#  yeah                                                                                                            3
#  """;;;;;;;;;;;                                                                                                  3
#  but it's not smart enough to say which pocket it is in """;;;;;;;;;;                                            2
#                                                                                                              ...
#  are making me feel yucky """;;;;;;;;;;;                                                                         1
#  you know i want cha&quot;" - aaarrrrrrrrr i repeat and repeat this song alllll day. it looks very stupid        1
#  for everything.""";;;;;;;;;;;                                                                                   1
#  ou pas  *va aller taper iTunes*""";;;;;;;;;;                                                                    1
#  i'm not complaining  #asot400""";;;;;;;;;;                                                                      1
# Name: Sentiment, Length: 1758, dtype: int64

# %%
train
# Out:
#        ItemID Sentiment                                      SentimentText
# 0           1         0                       is so sad for my APL frie...
# 1           2         0                     I missed the New Moon trail...
# 2           3         1                omg its already 7:30 :O;;;;;;;;;;;;
# 3           4         0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5         0           i think mi bf is cheating on me!!!   ...
# ...       ...       ...                                                ...
# 99784   99995         0  @cupati It took me waaay too long to get your ...
# 99785   99996         0  @Cupcake  seems like a repeating problem   hop...
# 99787   99998         0         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 99788   99999         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99789  100000         1        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [76949 rows x 3 columns]

# %%
train_1 = train[~train['Sentiment'].isin(["0","1"])]
value_counts_sentiment  = train_1['Sentiment'].value_counts()
trainG = pd.merge(train,train_1, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
trainG
# Out:
#        ItemID Sentiment                                      SentimentText
# 0           1         0                       is so sad for my APL frie...
# 1           2         0                     I missed the New Moon trail...
# 2           3         1                omg its already 7:30 :O;;;;;;;;;;;;
# 3           4         0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5         0           i think mi bf is cheating on me!!!   ...
# ...       ...       ...                                                ...
# 76944   99995         0  @cupati It took me waaay too long to get your ...
# 76945   99996         0  @Cupcake  seems like a repeating problem   hop...
# 76946   99998         0         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 76947   99999         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 76948  100000         1        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [75180 rows x 3 columns]

# %%
train_1
# Out:
#                                                   ItemID  \
# 115    116,0,"  told not to drink w/my Rx so just gav...
# 137                         138,1," &lt;"--- That is all
# 140    141,0," &quot; Vandals paint swastikas on home...
# 148                                   149,0," &quot;well
# 181    182,1," @adbert: &quot;"#Video [Woody Woodpeck...
# ...                                                  ...
# 98789  98999,1,"@cptkenz :o WTF?! that's such a long ...
# 98854  99064,0,"@Craftysince1990 Lol, that's sweet! I...
# 99269  99480,0,"@CrisiLouise I think otis is cos he h...
# 99562  99773,1,"@CrypticAwen i have seen him around, ...
# 99582  99793,0,"@crystal Twitter replies past the fir...
#
#                                                Sentiment  \
# 115                                                    v
# 137          and believe me.. it's enough!""";;;;;;;;;;;
# 140     lesbian church story : Naples Daily News&quot...
# 148     the truth is I miss you so&quot;"- Coldplay""...
# 181                                            @klitoria
# ...                                                  ...
# 98789                             though. """;;;;;;;;;;;
# 98854                             FOR SURE!""";;;;;;;;;;
# 99269                                 poor little bugger
# 99562                  everyone is welcome """;;;;;;;;;;
# 99582                         help please? """;;;;;;;;;;
#
#                                            SentimentText
# 115                                   sad.""";;;;;;;;;;;
# 137                                                  nan
# 140                                                  nan
# 148                                                  nan
# 181     just wishing to be a ch... â« http://blip.fm...
# ...                                                  ...
# 98789                                                nan
# 98854                                                nan
# 99269                           both arms """;;;;;;;;;;;
# 99562                                                nan
# 99582                                                nan
#
# [1769 rows x 3 columns]

# %%
value_counts_sentiment  = trainG['Sentiment'].value_counts()
value_counts_sentiment
# Out:
# 1    41696
# 0    33484
# Name: Sentiment, dtype: int64

# %%
test = test[test['SentimentText'].notna()]

# %%
patterns= ['[^!.?]+']

for tweet in trainG['SentimentText'] :
    #Convert to lower case
         tweet = tweet.lower()
         #Convert www.* or https?://* to URL
         tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
         #Convert @username to AT_USER
         tweet = re.sub('@[^\s]+','AT_USER',tweet)
         #Remove additional white spaces
         tweet = re.sub('[\s]+', ' ', tweet)
         #Replace #word with word
         tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
         #trim
         tweet = tweet.strip('\'"')
         
         
test['SentimentText'] = test['SentimentText'].astype(str)
for tweet in test['SentimentText'] :
    #Convert to lower case
         tweet = tweet.lower()
         #Convert www.* or https?://* to URL
         tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
         #Convert @username to AT_USER
         tweet = re.sub('@[^\s]+','AT_USER',tweet)
         #Remove additional white spaces
         tweet = re.sub('[\s]+', ' ', tweet)
         #Replace #word with word
         tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
         #trim
         tweet = tweet.strip('\'"')       
for tweet in trainG['SentimentText'] :
    for p in patterns:
        tweet = re.findall(p, tweet)

# %%
trainG
# Out:
#        ItemID Sentiment                                      SentimentText
# 0           1         0                       is so sad for my APL frie...
# 1           2         0                     I missed the New Moon trail...
# 2           3         1                omg its already 7:30 :O;;;;;;;;;;;;
# 3           4         0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5         0           i think mi bf is cheating on me!!!   ...
# ...       ...       ...                                                ...
# 76944   99995         0  @cupati It took me waaay too long to get your ...
# 76945   99996         0  @Cupcake  seems like a repeating problem   hop...
# 76946   99998         0         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 76947   99999         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 76948  100000         1        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [75180 rows x 3 columns]

# %%
import re
strip_special_chars = re.compile("[^A-Za-z0-9 ]+")

for string in trainG['SentimentText']:
    
    string = string.lower().replace("<br />", " ")
    string = re.sub(strip_special_chars, "", string.lower())    
    
trainG
# Out:
#        ItemID Sentiment                                      SentimentText
# 0           1         0                       is so sad for my APL frie...
# 1           2         0                     I missed the New Moon trail...
# 2           3         1                omg its already 7:30 :O;;;;;;;;;;;;
# 3           4         0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5         0           i think mi bf is cheating on me!!!   ...
# ...       ...       ...                                                ...
# 76944   99995         0  @cupati It took me waaay too long to get your ...
# 76945   99996         0  @Cupcake  seems like a repeating problem   hop...
# 76946   99998         0         @CuPcAkE_2120 ya i thought so ;;;;;;;;;;;;
# 76947   99999         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 76948  100000         1        @cupcake_kayla haha yes you do ;;;;;;;;;;;;
#
# [75180 rows x 3 columns]

# %%
trainG.shape
# Out:
# (75180, 3)

# %%
test.shape
# Out:
# (299045, 2)

# %%
trainG['SentimentText'] = trainG['SentimentText'].astype(str)
trainG = trainG[trainG['SentimentText'].notna()]

# %%
#Clean text from noise
def clean_text(text):
    #Filter to allow only alphabets
    text = re.sub(r'[^a-zA-Z\']', ' ', text)
    
    #Remove Unicode characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)
    
    #Convert to lowercase to maintain consistency
    text = text.lower()
       
    return text

# %%
trainG['SentimentText'] = trainG['SentimentText'].apply(lambda x:clean_text(x))

# %%
def tokenize(text): 
    tknzr = TweetTokenizer()
    return tknzr.tokenize(text)

def stem(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

en_stopwords = set(stopwords.words("english")) 

vectorizer = CountVectorizer(
    analyzer = 'word',
    tokenizer = tokenize,
    lowercase = True,
    ngram_range=(1, 1),
    stop_words = en_stopwords)

# %%
#data=pd.concat([trainG,test],sort=False).reset_index(drop=True)

# %%
#data

# %%
#data['SentimentText'] = data['SentimentText'].astype(str)

# %%
#Clean text from noise
def clean_text(text):
    #Filter to allow only alphabets
    text = re.sub(r'[^a-zA-Z\']', ' ', text)
    
    #Remove Unicode characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)
    
    #Convert to lowercase to maintain consistency
    text = text.lower()
       
    return text

# %%
#data['SentimentText']  =data['SentimentText'] .apply(lambda x:clean_text(x))

# %%
data = trainG.copy()
data.drop('ItemID', axis=1, inplace=True)

# %%
data.head()
# Out:
#   Sentiment                                      SentimentText
# 0         0                       is so sad for my apl frie...
# 1         0                     i missed the new moon trail...
# 2         1                omg its already       o
# 3         0               omgaga  im sooo  im gunna cry  i'...
# 4         0           i think mi bf is cheating on me      ...

# %%
print(data.isnull().any())
# Out:
# Sentiment        False
# SentimentText    False
# dtype: bool

# %%
data.dtypes
# Out:
# Sentiment        object
# SentimentText    object
# dtype: object

# %%
data['Sentiment'] = data['Sentiment'].astype('category')
print(type(data['Sentiment'][0]))
# Out:
# <class 'str'>

# %%
data['label_id'] = data['Sentiment'].cat.codes
data['label_id'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: label_id, dtype: int8

# %%
data
# Out:
#       Sentiment                                      SentimentText  label_id
# 0             0                       is so sad for my apl frie...         0
# 1             0                     i missed the new moon trail...         0
# 2             1                omg its already       o                     1
# 3             0               omgaga  im sooo  im gunna cry  i'...         0
# 4             0           i think mi bf is cheating on me      ...         0
# ...         ...                                                ...       ...
# 76944         0   cupati it took me waaay too long to get your ...         0
# 76945         0   cupcake  seems like a repeating problem   hop...         0
# 76946         0          cupcake      ya i thought so                      0
# 76947         1   cupcake dollie yes  yes  i'm glad you had mor...         1
# 76948         1         cupcake kayla haha yes you do                      1
#
# [75180 rows x 3 columns]

# %%
test.tail()
# Out:
#                                                    ItemID  \
# 299040  299996,"@martine2323 'Morning, Petal - work br...
# 299041  299997,"@martinetrene Hello,little bird!  i fi...
# 299042                                             299998
# 299043                                             299999
# 299044                                             300000
#
#                                             SentimentText
# 299040                                                nan
# 299041                                                nan
# 299042  @MartinezMayra I got u at work when I go buy o...
# 299043  @martinfaux He certainly gives good interview ...
# 299044  @martinfaux we've the feedback about our brows...

# %%
trainG.to_excel("trainG_clean.xlsx", sheet_name='global', index=False)
test.to_excel("test_clean.xlsx",sheet_name = "gloabl" , index = False)
